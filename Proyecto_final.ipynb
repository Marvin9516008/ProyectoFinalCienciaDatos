# %%
import pandas as pd
import numpy as np

# %%
archivo = pd.read_csv("C:/Users/hvasquez/Downloads/sales_data_sample.csv", sep=';')
archivo.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#           ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0    2/24/2003 0:00  Shipped       1         2     2003  ...
# 1   5/07/2003 00:00  Shipped       2         5     2003  ...
# 2   7/01/2003 00:00  Shipped       3         7     2003  ...
# 3    8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 00:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# 1             59 rue de l'Abbaye           NaN          Reims   NaN
# 2  27 rue du Colonel Pierre Avia           NaN          Paris   NaN
# 3             78934 Hillside Dr.           NaN       Pasadena    CA
# 4                7734 Strong St.           NaN  San Francisco    CA
#
#   POSTALCODE COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 0      10022     USA       NaN              Yu             Kwai    Small
# 1      51100  France      EMEA         Henriot             Paul    Small
# 2      75508  France      EMEA        Da Cunha           Daniel   Medium
# 3      90003     USA       NaN           Young            Julie   Medium
# 4        NaN     USA       NaN           Brown            Julie   Medium
#
# [5 rows x 25 columns]

# %%
archivo.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE',
#        'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE'],
#       dtype='object')

# %%
archivo.SALES.sum()
# Out:
# 10032628.85

# %%
archivo['PRODUCTLINE'].unique()
# Out:
# array(['Motorcycles', 'Classic Cars', 'Trucks and Buses', 'Vintage Cars',
#        'Planes', 'Ships', 'Trains'], dtype=object)

# %%
dim_product = pd.DataFrame(archivo['PRODUCTLINE'].unique(), columns = ['PRODUCTLINE'] )
dim_product
# Out:
#         PRODUCTLINE
# 0       Motorcycles
# 1      Classic Cars
# 2  Trucks and Buses
# 3      Vintage Cars
# 4            Planes
# 5             Ships
# 6            Trains

# %%
#np.arange(1,len(dim_product)+1)
# Out:
# array([1, 2, 3, 4, 5, 6, 7])

# %%
#np.arange(len(pd.DataFrame(archivo['PRODUCTLINE'].unique())))
# Out:
# array([0, 1, 2, 3, 4, 5, 6])

# %%
dim_product.insert(loc=0, column='product_id', value = np.arange(1,len(dim_product)+1))
dim_product
# Out:
#    product_id       PRODUCTLINE
# 0           1       Motorcycles
# 1           2      Classic Cars
# 2           3  Trucks and Buses
# 3           4      Vintage Cars
# 4           5            Planes
# 5           6             Ships
# 6           7            Trains

# %%
geografia = archivo[['COUNTRY','CITY','STATE','TERRITORY']]
dim_geografia = geografia.drop_duplicates()
dim_geografia.insert(loc=0, column='geografia_id', value = np.arange(1,len(dim_geografia)+1))

# %%
dim_geografia
# Out:
#      geografia_id    COUNTRY           CITY     STATE TERRITORY
# 0               1        USA            NYC        NY       NaN
# 1               2     France          Reims       NaN      EMEA
# 2               3     France          Paris       NaN      EMEA
# 3               4        USA       Pasadena        CA       NaN
# 4               5        USA  San Francisco        CA       NaN
# ..            ...        ...            ...       ...       ...
# 481            71      Italy        Bergamo       NaN      EMEA
# 483            72  Australia   Glen Waverly  Victoria      APAC
# 554            73        USA       Glendale        CT       NaN
# 567            74    Germany         Munich       NaN      EMEA
# 571            75    Belgium      Charleroi       NaN      EMEA
#
# [75 rows x 5 columns]

# %%
dim_dealer = pd.DataFrame(archivo['DEALSIZE'].unique(), columns = ['DEALSIZE'] )
dim_dealer.insert(loc=0, column='dealer_id', value = np.arange(1,len(dim_dealer)+1))
dim_dealer
# Out:
#    dealer_id DEALSIZE
# 0          1    Small
# 1          2   Medium
# 2          3    Large

# %%
customer = archivo[['CUSTOMERNAME','PHONE','CONTACTFIRSTNAME','CONTACTLASTNAME']]
dim_customer = customer.drop_duplicates()
dim_customer.insert(loc=0, column='customer_id', value = np.arange(1,len(dim_customer)+1))
dim_customer
# Out:
#      customer_id                       CUSTOMERNAME              PHONE  \
# 0              1                  Land of Toys Inc.         2125557818
# 1              2                 Reims Collectables         26.47.1555
# 2              3                    Lyon Souveniers   +33 1 46 62 7555
# 3              4                  Toys4GrownUps.com         6265557265
# 4              5           Corporate Gift Ideas Co.         6505551386
# ..           ...                                ...                ...
# 483           88        Australian Collectables Ltd     61-9-3844-6555
# 554           89                   Gift Ideas Corp.         2035554407
# 567           90  Bavarian Collectables Imports Co.  +49 89 61 08 9555
# 571           91                       Royale Belge   (071) 23 67 2555
# 937           92            Auto-Moto Classics Inc.         6175558428
#
#     CONTACTFIRSTNAME CONTACTLASTNAME
# 0               Kwai              Yu
# 1               Paul         Henriot
# 2             Daniel        Da Cunha
# 3              Julie           Young
# 4              Julie           Brown
# ..               ...             ...
# 483             Sean         Connery
# 554              Dan           Lewis
# 567          Michael     Donnermeyer
# 571          Pascale        Cartrain
# 937           Leslie          Taylor
#
# [92 rows x 5 columns]

# %%
date = archivo[['ORDERDATE','QTR_ID', 'MONTH_ID', 'YEAR_ID']]
dim_tiempo = date.drop_duplicates()
dim_tiempo.insert(loc=0, column='tiempo_id', value = np.arange(1,len(dim_tiempo)+1))
dim_tiempo
# Out:
#       tiempo_id         ORDERDATE  QTR_ID  MONTH_ID  YEAR_ID
# 0             1    2/24/2003 0:00       1         2     2003
# 1             2   5/07/2003 00:00       2         5     2003
# 2             3   7/01/2003 00:00       3         7     2003
# 3             4    8/25/2003 0:00       3         8     2003
# 4             5  10/10/2003 00:00       4        10     2003
# ...         ...               ...     ...       ...      ...
# 2251        248   4/11/2003 00:00       2         4     2003
# 2306        249    8/13/2003 0:00       3         8     2003
# 2356        250  10/08/2003 00:00       4        10     2003
# 2532        251    3/28/2005 0:00       1         3     2005
# 2692        252    4/21/2003 0:00       2         4     2003
#
# [252 rows x 5 columns]

# %%
fact_custom = dim_customer.merge(archivo[['ORDERDATE','PRODUCTLINE','COUNTRY','CITY','STATE','TERRITORY','DEALSIZE','CUSTOMERNAME','ORDERNUMBER', 'QUANTITYORDERED','ORDERLINENUMBER','SALES']], left_on='CUSTOMERNAME', right_on='CUSTOMERNAME')

fact_custom.head()
# Out:
#    customer_id       CUSTOMERNAME       PHONE CONTACTFIRSTNAME  \
# 0            1  Land of Toys Inc.  2125557818             Kwai
# 1            1  Land of Toys Inc.  2125557818             Kwai
# 2            1  Land of Toys Inc.  2125557818             Kwai
# 3            1  Land of Toys Inc.  2125557818             Kwai
# 4            1  Land of Toys Inc.  2125557818             Kwai
#
#   CONTACTLASTNAME        ORDERDATE  PRODUCTLINE COUNTRY CITY STATE TERRITORY  \
# 0              Yu   2/24/2003 0:00  Motorcycles     USA  NYC    NY       NaN
# 1              Yu  11/15/2004 0:00  Motorcycles     USA  NYC    NY       NaN
# 2              Yu   2/24/2003 0:00  Motorcycles     USA  NYC    NY       NaN
# 3              Yu  11/15/2004 0:00  Motorcycles     USA  NYC    NY       NaN
# 4              Yu   2/24/2003 0:00  Motorcycles     USA  NYC    NY       NaN
#
#   DEALSIZE  ORDERNUMBER  QUANTITYORDERED  ORDERLINENUMBER    SALES
# 0    Small        10107               30                2  2871.00
# 1   Medium        10329               42                1  4396.14
# 2   Medium        10107               39                5  3896.49
# 3   Medium        10329               20                2  3176.00
# 4   Medium        10107               27                4  6065.55

# %%
fact_product = dim_product.merge(fact_custom, left_on='PRODUCTLINE', right_on='PRODUCTLINE')

fact_product.head()
# Out:
#    product_id  PRODUCTLINE  customer_id       CUSTOMERNAME       PHONE  \
# 0           1  Motorcycles            1  Land of Toys Inc.  2125557818
# 1           1  Motorcycles            1  Land of Toys Inc.  2125557818
# 2           1  Motorcycles            1  Land of Toys Inc.  2125557818
# 3           1  Motorcycles            1  Land of Toys Inc.  2125557818
# 4           1  Motorcycles            1  Land of Toys Inc.  2125557818
#
#   CONTACTFIRSTNAME CONTACTLASTNAME        ORDERDATE COUNTRY CITY STATE  \
# 0             Kwai              Yu   2/24/2003 0:00     USA  NYC    NY
# 1             Kwai              Yu  11/15/2004 0:00     USA  NYC    NY
# 2             Kwai              Yu   2/24/2003 0:00     USA  NYC    NY
# 3             Kwai              Yu  11/15/2004 0:00     USA  NYC    NY
# 4             Kwai              Yu   2/24/2003 0:00     USA  NYC    NY
#
#   TERRITORY DEALSIZE  ORDERNUMBER  QUANTITYORDERED  ORDERLINENUMBER    SALES
# 0       NaN    Small        10107               30                2  2871.00
# 1       NaN   Medium        10329               42                1  4396.14
# 2       NaN   Medium        10107               39                5  3896.49
# 3       NaN   Medium        10329               20                2  3176.00
# 4       NaN   Medium        10107               27                4  6065.55

# %%
fact_geo = dim_geografia.merge(fact_product, left_on=['COUNTRY','CITY',dim_geografia['STATE'].mask(pd.isnull, dim_geografia['TERRITORY'])]
                                         , right_on=['COUNTRY','CITY',fact_product['STATE'].mask(pd.isnull, fact_product['TERRITORY'])])

fact_geo.head()
# Out:
#    geografia_id COUNTRY key_2 CITY STATE_x TERRITORY_x  product_id  \
# 0             1     USA    NY  NYC      NY         NaN           1
# 1             1     USA    NY  NYC      NY         NaN           1
# 2             1     USA    NY  NYC      NY         NaN           1
# 3             1     USA    NY  NYC      NY         NaN           1
# 4             1     USA    NY  NYC      NY         NaN           1
#
#    PRODUCTLINE  customer_id       CUSTOMERNAME  ... CONTACTFIRSTNAME  \
# 0  Motorcycles            1  Land of Toys Inc.  ...             Kwai
# 1  Motorcycles            1  Land of Toys Inc.  ...             Kwai
# 2  Motorcycles            1  Land of Toys Inc.  ...             Kwai
# 3  Motorcycles            1  Land of Toys Inc.  ...             Kwai
# 4  Motorcycles            1  Land of Toys Inc.  ...             Kwai
#
#   CONTACTLASTNAME        ORDERDATE STATE_y TERRITORY_y DEALSIZE ORDERNUMBER  \
# 0              Yu   2/24/2003 0:00      NY         NaN    Small       10107
# 1              Yu  11/15/2004 0:00      NY         NaN   Medium       10329
# 2              Yu   2/24/2003 0:00      NY         NaN   Medium       10107
# 3              Yu  11/15/2004 0:00      NY         NaN   Medium       10329
# 4              Yu   2/24/2003 0:00      NY         NaN   Medium       10107
#
#    QUANTITYORDERED  ORDERLINENUMBER    SALES
# 0               30                2  2871.00
# 1               42                1  4396.14
# 2               39                5  3896.49
# 3               20                2  3176.00
# 4               27                4  6065.55
#
# [5 rows x 21 columns]

# %%
fact_tiempo = dim_tiempo.merge(fact_geo, left_on='ORDERDATE', right_on='ORDERDATE')

fact_tiempo.head()
# Out:
#    tiempo_id       ORDERDATE  QTR_ID  MONTH_ID  YEAR_ID  geografia_id COUNTRY  \
# 0          1  2/24/2003 0:00       1         2     2003             1     USA
# 1          1  2/24/2003 0:00       1         2     2003             1     USA
# 2          1  2/24/2003 0:00       1         2     2003             1     USA
# 3          1  2/24/2003 0:00       1         2     2003             1     USA
# 4          1  2/24/2003 0:00       1         2     2003             1     USA
#
#   key_2 CITY STATE_x  ...       PHONE  CONTACTFIRSTNAME CONTACTLASTNAME  \
# 0    NY  NYC      NY  ...  2125557818              Kwai              Yu
# 1    NY  NYC      NY  ...  2125557818              Kwai              Yu
# 2    NY  NYC      NY  ...  2125557818              Kwai              Yu
# 3    NY  NYC      NY  ...  2125557818              Kwai              Yu
# 4    NY  NYC      NY  ...  2125557818              Kwai              Yu
#
#    STATE_y TERRITORY_y DEALSIZE ORDERNUMBER QUANTITYORDERED ORDERLINENUMBER  \
# 0       NY         NaN    Small       10107              30               2
# 1       NY         NaN   Medium       10107              39               5
# 2       NY         NaN   Medium       10107              27               4
# 3       NY         NaN   Medium       10107              21               1
# 4       NY         NaN    Small       10107              29               6
#
#      SALES
# 0  2871.00
# 1  3896.49
# 2  6065.55
# 3  3036.60
# 4  2055.23
#
# [5 rows x 25 columns]

# %%
fact_dealer = dim_dealer.merge(fact_tiempo, left_on='DEALSIZE', right_on='DEALSIZE')

fact_dealer.head()
# Out:
#    dealer_id DEALSIZE  tiempo_id        ORDERDATE  QTR_ID  MONTH_ID  YEAR_ID  \
# 0          1    Small          1   2/24/2003 0:00       1         2     2003
# 1          1    Small          1   2/24/2003 0:00       1         2     2003
# 2          1    Small          1   2/24/2003 0:00       1         2     2003
# 3          1    Small          1   2/24/2003 0:00       1         2     2003
# 4          1    Small          2  5/07/2003 00:00       2         5     2003
#
#    geografia_id COUNTRY key_2  ...        CUSTOMERNAME       PHONE  \
# 0             1     USA    NY  ...   Land of Toys Inc.  2125557818
# 1             1     USA    NY  ...   Land of Toys Inc.  2125557818
# 2             1     USA    NY  ...   Land of Toys Inc.  2125557818
# 3             1     USA    NY  ...   Land of Toys Inc.  2125557818
# 4             2  France  EMEA  ...  Reims Collectables  26.47.1555
#
#   CONTACTFIRSTNAME  CONTACTLASTNAME STATE_y  TERRITORY_y ORDERNUMBER  \
# 0             Kwai               Yu      NY          NaN       10107
# 1             Kwai               Yu      NY          NaN       10107
# 2             Kwai               Yu      NY          NaN       10107
# 3             Kwai               Yu      NY          NaN       10107
# 4             Paul          Henriot     NaN         EMEA       10121
#
#   QUANTITYORDERED ORDERLINENUMBER    SALES
# 0              30               2  2871.00
# 1              29               6  2055.23
# 2              25               3  2845.75
# 3              20               8  1858.00
# 4              34               5  2765.90
#
# [5 rows x 26 columns]

# %%
fact_table = fact_dealer[['customer_id','product_id','geografia_id','tiempo_id','dealer_id','ORDERNUMBER','QUANTITYORDERED','ORDERLINENUMBER','SALES']]
fact_table.insert(loc=0, column='sales_id', value = np.arange(1,len(fact_table)+1))
fact_table
# Out:
#       sales_id  customer_id  product_id  geografia_id  tiempo_id  dealer_id  \
# 0            1            1           1             1          1          1
# 1            2            1           1             1          1          1
# 2            3            1           1             1          1          1
# 3            4            1           1             1          1          1
# 4            5            2           1             2          2          1
# ...        ...          ...         ...           ...        ...        ...
# 2818      2819           26           4            21        201          3
# 2819      2820           68           4            56        202          3
# 2820      2821           13           5            10        214          3
# 2821      2822           13           5            10        214          3
# 2822      2823           88           2            72        226          3
#
#       ORDERNUMBER  QUANTITYORDERED  ORDERLINENUMBER    SALES
# 0           10107               30                2  2871.00
# 1           10107               29                6  2055.23
# 2           10107               25                3  2845.75
# 3           10107               20                8  1858.00
# 4           10121               34                5  2765.90
# ...           ...              ...              ...      ...
# 2818        10214               50                1  9534.50
# 2819        10344               45                1  7650.00
# 2820        10401               85               10  7543.75
# 2821        10401               77                9  7084.00
# 2822        10265               49                1  8427.02
#
# [2823 rows x 10 columns]

# %%
import os
import configparser

# %%
config = configparser.ConfigParser()
config.read_file(open('C:/Users/hvasquez/Downloads/dwh_sales.cfg'))

# %%
ENDPOINT = config.get('REDSHIFT','HOST')

# %%
ENDPOINT
# Out:
# 'sales-cluster.ctebafejoguu.us-east-2.redshift.amazonaws.com'

# %%
ENDPOINT = config.get('REDSHIFT','HOST')
DB_USER = config.get('REDSHIFT','DB_USER')
DB_PASSWORD = config.get('REDSHIFT','DB_PASSWORD')
DB_PORT = config.get('REDSHIFT','DB_PORT')
DB_NAME = config.get('REDSHIFT','DB_NAME')

# %%
redshift_conn_string = "postgresql://{}:{}@{}:{}/{}".format(DB_USER, DB_PASSWORD, ENDPOINT, DB_PORT, DB_NAME)
print(redshift_conn_string)
# Out:
# postgresql://awsuser:*Redshift1$@sales-cluster.ctebafejoguu.us-east-2.redshift.amazonaws.com:5439/dev

# %%
# %sql $redshift_conn_string
# Out:
# UsageError: Line magic function `%Sql` not found.

# %%
from sqlalchemy import create_engine

# %%
conn = create_engine(redshift_conn_string)

# %%
#insertar dimension producto
dim_product.to_sql('dim_product', conn, index=False, if_exists='append',method = 'multi')
# Out:
# 7

# %%
#insertar dimension geografia
dim_geografia.to_sql('dim_geografia', conn, index=False, if_exists='append')
# Out:
# 75

# %%
#insertar dimension dealer
dim_dealer.to_sql('dim_dealer', conn, index=False, if_exists='append')
# Out:
# 3

# %%
#insertar dimension customer
dim_customer.to_sql('dim_customer', conn, index=False, if_exists='append')
# Out:
# 92

# %%
#insertar dimension tiempo
dim_tiempo.to_sql('dim_tiempo', conn, index=False, if_exists='append')
# Out:
# 252

# %%
#insertar fact table
fact_table.to_sql('fact_table', conn, index=False, if_exists='append')
# Out:
# 2823
